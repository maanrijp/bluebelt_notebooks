# %%
import pandas as pd
import numpy as np
import bluebelt as blue

# %%
index = ['vast', 'flex', 'bruto', 'afwezig', 'nbsb', 'netto']
measure = ['relative', 'relative', 'total', 'relative', 'relative', 'total']
data = [0.7, 0.3, 1, -.13, -0.12, 0.75]
series = pd.Series(index=index, data=data)

# %%
series.blue.graph.waterfall(measure=measure, title='test', inverse=False, horizontal=False, ylim=(0,1), format_yticks='%')
