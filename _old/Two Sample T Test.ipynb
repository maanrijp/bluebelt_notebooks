# %%
import pandas as pd
import numpy as np
import bluebelt as blue
import scipy.stats as stats

# %%
df = pd.read_excel("data/correlation_data.xlsx")
df.columns = ['first', 'second', 'third', 'fourth']

# %%
tst = df.blue.test.two_sample_t(columns=['first','fourth'], related=False)

# %%
tst.statistic
# Out:
# -1.1596717949173188

# %%
tst.plot()
