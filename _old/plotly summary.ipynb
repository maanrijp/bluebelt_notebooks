# %%
import pandas as pd
import numpy as np
import bluebelt as blue

# %%
y = np.random.normal(50,10,100)

# %%
s = pd.Series(data=y, index=pd.date_range(start="1-1-2020", periods=100), name='main process')
s.iloc[37]=117
s.iloc[42]=0

# %%
summary = s.blue.ppa.summary()

# %%
summary.plot()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fig = make_subplots(rows=4, cols=1,
                    row_heights=[3,1,1,1],
                    shared_xaxes=True,
                    vertical_spacing=0.)

fig.add_trace(go.Histogram(x=s.values),
              row=1, col=1)

fig.add_trace(go.Box(x=s.values),
              row=2, col=1)
fig.add_trace(go.Scatter(x=s.index, y=s.values),
              row=3, col=1)
fig.add_trace(go.Scatter(x=s.index, y=s.values),
              row=4, col=1)

fig.show()
# Out:
# <div>                            <div id="77bec939-bf1a-48e0-bc5d-187efa84d543" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77bec939-bf1a-48e0-bc5d-187efa84d543")) {                    Plotly.newPlot(                        "77bec939-bf1a-48e0-bc5d-187efa84d543",                        [{"type": "histogram", "x": [59.24617565836186, 29.79748787115682, 44.887400804274854, 49.36736756618147, 54.8761623161626, 33.195780628013736, 42.57369253464107, 46.92912740865738, 38.29359082411986, 71.53008229127005, 40.06289509603087, 41.545444776377025, 56.76320266185778, 42.490271295998724, 39.703963678479184, 58.98244115210702, 52.65516833003099, 43.00486381855308, 63.74095932659366, 39.21816070907879, 53.24982079169844, 46.07308012481639, 48.94752384242531
# ...
