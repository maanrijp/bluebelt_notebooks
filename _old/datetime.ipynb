# %%
import pandas as pd
import numpy as np
import bluebelt as blue

# %%
n = 365
np.random.seed(25)
series = pd.Series(np.random.weibull(7,n), index=pd.date_range(start='1-1-2020', periods=n), name='main process')

# %%
series.blue.datetime.week_day().plot()

# %%
series.blue.datetime.week().plot()

# %%
series.blue.datetime.month().plot()

# %%
series.blue.datetime.day().plot()
