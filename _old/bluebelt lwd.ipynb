# %%
import pandas as pd
import numpy as np
import bluebelt as blue
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
n = 100
np.random.seed(27)
series = pd.Series(np.random.weibull(7,n), index=pd.date_range(start='1-1-2020', periods=n), name='main process')
#series = pd.Series(np.random.weibull(7,n), name='main process')
#series = pd.Series(np.random.randint(100,200,n), index=pd.date_range(start='1-1-2020', periods=n), name='main process')

# %%
series.iloc[10] = None

# %%
pca = series.blue.ppa.process_capability(target=1, lsl=0.8, subgroup_size=1)

# %%
pca
# Out:
# ProcessCapability(n=100, target=1, lsl=0.8, usl=None)

# %%
pca.plot()

# %%
series.min()
# Out:
# 0.5419040060363258

# %%
pca.max
# Out:
# 1.2509133245181725

# %%
print(pca)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e94a56b21d62> in <module>
# ----> 1 print(pca)
#
# ~/Projects/bluebelt_package/bluebelt/analysis/ppa.py in __str__(self)
#    1076                 f'{str_usl:{fill}}{self.usl}\n' +
#    1077                 f'{str_lt_lsl:{fill}}{self.lt_lsl:1.4f}\n' +
# -> 1078                 f'{str_gt_usl:{fill}}{self.gt_usl:1.4f}\n' +
#    1079                 f'{str_observed_performance:{fill}}{self.observed_performance:1.4f}\n' +
#    1080                 f'{str_pp:{fill}}{self.pp:1.4f}\n' +
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
# Out:
# 0.6914624612740131
