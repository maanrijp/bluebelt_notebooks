# %%
import pandas as pd
import numpy as np
import bluebelt as blue
from scipy.special import gamma

# %%
df = pd.read_excel("/Users/Arvid/Downloads/Piston Ring Diameter.xlsx")

# %%
series = df['Diameter']

# %%
pca = series.blue.ppa.process_capability(target=74, lsl=73.95, usl=74.05, subgroup_size=5)

# %%
pca.plot(figsize=(16,9))

# %%
pca.result
# Out:
# Process Data                       Potential Capability               Overall Capability
# target         74                  Cp             1.66                Pp             1.63
# LSL            73.95000            Cpl            1.69                Ppl            1.67
# USL            74.05000            Cpu            1.62                Ppu            1.60
# mean           74.00118            Cpk            1.62                Ppk            1.60
# n              125                 CCpk           1.66                Cpm            1.63
# std within     0.01007
# std overall    0.01020
#
# Observed Performance               Expected Performance (Within)      Expected Performance (Overall)
# PPM < LSL      0                   PPM < LSL      0                   PPM < LSL      0
# PPM > USL      0                   PPM > USL      0                   PPM > USL      1
# PPM            0 (0.00%)           PPM            1 (0.00%)           PPM            1 (0.00%)

# %%
pca.subgroups
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  74.030  74.002  74.019  73.992  74.008  73.995  73.992  74.001  74.011
# 1  74.009  73.994  73.997  73.985  73.993  73.995  74.006  73.994  74.000
# 2  73.994  73.998  73.994  73.995  73.990  74.004  74.000  74.007  74.000
# 3  74.000  73.984  74.005  73.998  73.996  73.994  74.012  73.986  74.005
# 4  73.982  74.001  74.015  74.005  73.996  74.004  73.999  73.990  74.006
#
#        9   ...      15      16      17      18      19      20      21  \
# 0  74.004  ...  74.002  73.996  73.993  74.015  74.009  73.992  74.007
# 1  74.005  ...  74.008  73.995  74.009  74.005  74.004  73.998  74.000
# 2  73.996  ...  74.006  73.967  73.994  74.000  73.984  74.012  74.014
# 3  74.007  ...  73.984  74.002  74.003  74.005  73.997  74.000  74.010
# 4  74.009  ...  74.015  74.008  73.993  74.000  74.010  73.982  73.984
#
#        22      23      24
# 0  74.015  73.989  74.014
# 1  73.990  74.007  73.995
# ...

# %%
pca.std_within
# Out:
# 0.010066712202701958
