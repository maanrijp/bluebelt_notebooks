# %%
import pandas as pd
import numpy as np
import bluebelt as blue

# %%
df = pd.read_excel("data/correlation_data.xlsx")
df.columns = ['first', 'second', 'third', 'fourth']

# %%
corr = df.blue.statistics.correlation(confidence=0.95)

# %%
corr.result()
# Out:
#         first                 second                  third                 fourth
#             r              CI      r              CI      r              CI      r              CI
# first                          0.612    [0.6, 0.625]  0.977  [0.976, 0.978]  0.993  [0.992, 0.993]
# second  0.612    [0.6, 0.625]                         0.592  [0.579, 0.605]  0.613    [0.6, 0.626]
# third   0.977  [0.976, 0.978]  0.592  [0.579, 0.605]                         0.968  [0.967, 0.969]
# fourth  0.993  [0.992, 0.993]  0.613    [0.6, 0.626]  0.968  [0.967, 0.969]

# %%
corr
# Out:
# Correlation(columns=['first', 'second', 'third', 'fourth'], nrows=100, ncols=4, confidence=0.95)

# %%
corr.plot()

# %%
df.iloc[:,0]
# Out:
# 0     28
# 1     15
# 2     68
# 3     10
# 4     30
#       ..
# 95    62
# 96    26
# 97    51
# 98    42
# 99     4
# Name: first, Length: 100, dtype: int64
