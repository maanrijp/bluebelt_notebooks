# %%
import pandas as pd
import numpy as np
import bluebelt as blue
import matplotlib.pyplot as plt

# %%
nrows = 5000
ncols = 6

np.random.seed(27)
series = pd.Series(np.random.weibull(7,nrows) * 100, index=pd.date_range(start='1-1-2020', periods=nrows), name='process A')
frame = pd.DataFrame(np.random.normal(loc=100, scale=20, size=ncols*nrows).reshape(nrows, ncols), index=pd.date_range(start='1-1-2020', periods=nrows), columns=[f'process {col}' for col in range(1, ncols+1)])

# %%
series.blue.datetime.week_day().means
# Out:
# Monday       93.427403
# Tuesday      93.574122
# Wednesday    93.550168
# Thursday     92.611913
# Friday       93.907496
# Saturday     94.232374
# Sunday       93.993725
# dtype: float64

# %%
series.blue.datetime.week_day().plot(figsize=(12,3))

# %%
series.blue.datetime.week_day().means
# Out:
# Monday       93.427403
# Tuesday      93.574122
# Wednesday    93.550168
# Thursday     92.611913
# Friday       93.907496
# Saturday     94.232374
# Sunday       93.993725
# dtype: float64

# %%
series.blue.datetime.weekday().normal_distribution
# Out:
# Monday       False
# Tuesday      False
# Wednesday    False
# Thursday     False
# Friday       False
# Saturday     False
# Sunday       False
# dtype: bool

# %%
series.blue.datetime.month_day().plot()

# %%
series.blue.datetime.week().plot()

# %%
series.blue.datetime.month().plot()

# %%
series.blue.datetime.year().plot()

# %%
series.blue.datetime.year().means
# Out:
# 2020    94.780969
# 2021    91.847686
# 2022    93.350183
# 2023    94.371701
# 2024    92.965898
# 2025    94.251653
# 2026    94.486907
# 2027    93.004504
# 2028    95.609340
# 2029    93.655512
# 2030    93.125580
# 2031    92.703547
# 2032    93.385607
# 2033    92.788265
# dtype: float64

# %%
# break the series
breaks = series.shape[0] // 5
loc = list(np.arange(0+breaks, series.shape[0], breaks))
series.iloc[loc] = np.nan

# break the frame
breaks = frame.shape[0] // 5
loc = list(np.arange(0+breaks, frame.shape[0], breaks))
for x in range(frame.shape[1]):
    frame.iloc[loc,x] = np.nan

# %%
series.blue.datetime.week_day().plot(figsize=(12,3))

# %%
series.blue.datetime.week_day()
# Out:
# WeekDay(series='process A', equal_means=True, equal_variances=True)
